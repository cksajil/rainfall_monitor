# %%
# Import Libraries needed
import librosa
import numpy as np
import pandas as pd
from tqdm import tqdm
from os import listdir
from os.path import join
from datetime import datetime, timedelta

# %%
# Set file paths for mechanical readings csv and wav file location
DATA_PATH = "/kaggle/input/rain-data-master-8k-10-sec"
MECH_FILE_PATH = "/kaggle/input/rain-data-master-8k-10-sec/davis_label_10_sec.csv"
NON_MECH_PATH = "/kaggle/input/rain-data-master-8k-10-sec/rainfall_sound_8k_10_sec"
Fs = 16000
MAX_LEN = 32000 # 2 seconds @ Fs 16k samples/sec

# %%
# Read mechanical raingauge readings as csv using pandas
mech_data = pd.read_csv(join(DATA_PATH, MECH_FILE_PATH))

# Convert time column to pandas time datatype
mech_data["time"]= pd.to_datetime(mech_data["time"])

# Get list of wav files and sort them in ascending order
wave_files = sorted(listdir(NON_MECH_PATH))

# Get total count of wav files available
N = len(wave_files)

# %%
# Function to parse date and time components from wav filenames
def filename_parser(filename):
    year, month, day, hour, minute, second, _ = map(int, filename.split(".")[0].split("_"))
    return datetime(year, month, day, hour, minute, second)

# Get the fist starting time available for wav files
start_time = filename_parser(wave_files[0])

# Get the last time available for wav files
end_time = filename_parser(wave_files[-1])

# %%
# Find overlapping time instances where mechanical readings and wav files are available
row_overlap = (mech_data["time"]>start_time)&(mech_data["time"]<end_time)
mech_data = mech_data[row_overlap]

# %%
mech_data["time_delta"] = mech_data["time"].diff()
mech_data["time_delta"] = mech_data["time_delta"].dt.total_seconds()

# %%
# To find the number of unique days where we have recording available
mech_data["time"] = mech_data["time"].astype('str')
mech_data[["YMD", "HMS"]] = mech_data["time"].str.split(" ",expand=True)
mech_data["YMD"].value_counts().keys()
# Out:
# Index(['2024-04-12', '2024-04-13', '2024-04-11', '2024-04-15', '2024-04-14'], dtype='object', name='YMD')

# %%
mech_data["time"]= pd.to_datetime(mech_data["time"])
mech_data = mech_data[["time", "rainfall"]]

# %%
# mech_data = mech_data[mech_data["rainfall"]!=0.0]

# %%
mech_data
# Out:
#                           time  rainfall
# 0   2024-04-11 22:20:59.757439       0.0
# 1   2024-04-11 22:21:09.757439       0.0
# 2   2024-04-11 22:21:19.757438       0.0
# 3   2024-04-11 22:21:29.757440       0.0
# 4   2024-04-11 22:21:39.757440       0.0
# ..                         ...       ...
# 282 2024-04-15 06:00:19.766818       0.2
# 283 2024-04-15 06:00:29.757440       0.0
# 284 2024-04-15 06:00:39.757441       0.0
# 285 2024-04-15 06:00:49.757439       0.0
# 286 2024-04-15 06:00:59.757438       0.0
#
# [287 rows x 2 columns]

# %%
# Function to load a wav file using librosa and get its sampling rate and duration
def load_wav(file_path, Fs=Fs):
    audio, Fs = librosa.load(file_path, sr=Fs)
    duration = librosa.get_duration(y=audio, sr=Fs)
    return audio, Fs, duration

# %%
mech_data
# Out:
#                           time  rainfall
# 0   2024-04-11 22:20:59.757439       0.0
# 1   2024-04-11 22:21:09.757439       0.0
# 2   2024-04-11 22:21:19.757438       0.0
# 3   2024-04-11 22:21:29.757440       0.0
# 4   2024-04-11 22:21:39.757440       0.0
# ..                         ...       ...
# 282 2024-04-15 06:00:19.766818       0.2
# 283 2024-04-15 06:00:29.757440       0.0
# 284 2024-04-15 06:00:39.757441       0.0
# 285 2024-04-15 06:00:49.757439       0.0
# 286 2024-04-15 06:00:59.757438       0.0
#
# [287 rows x 2 columns]

# %%
def get_fname_time(file_name):
    file_name_short = file_name.split("_")[:-1]
    year, month, day, hour, minute, second = map(int, file_name_short)
    fname_time = datetime(year, month, day, hour, minute, second)
    return fname_time

def ftime_to_fname(ftime):
    ftime_prev = ftime.strftime('%Y_%m_%d_%H_%M_%S')
    return ftime_prev

def get_previous_file(file_name, wave_files):
    fname_time = get_fname_time(file_name)
    fname_time_prev = fname_time-timedelta(seconds=10)
    prev_file_name = ftime_to_fname(fname_time_prev)
    prev_file_to_read = None
    for wave_file in wave_files:
        wave_file_short = "_".join(wave_file.split("_")[:-1])
        if wave_file_short == prev_file_name:
            prev_file_to_read = wave_file
            break
        else:
            continue
    return prev_file_to_read

def evaluate_duration(duration):
    sec_difference = duration.total_seconds()
    if sec_difference<0:
        selection_flag = False
        partial = False
        current_file_init_secs = 0
        prev_file_end_secs = 0
    elif sec_difference==0:
        selection_flag = True
        partial = False
        current_file_init_secs = 10
        prev_file_end_secs = 0
    elif sec_difference>9:
        selection_flag = False
        partial = False
        current_file_init_secs = 0
        prev_file_end_secs = 0
    elif sec_difference<=9:
        selection_flag = True
        partial = True
        current_file_init_secs = 10-sec_difference
        prev_file_end_secs  = sec_difference
    return selection_flag, partial, current_file_init_secs, prev_file_end_secs

def read_and_merge_files(file_path_1, file_path_2, current_file_init_secs, prev_file_end_secs):
    audio_1, _, _ = load_wav(file_path_1)
    audio_2, _, _ = load_wav(file_path_2)
    audio_1 = audio_1[:int(current_file_init_secs*Fs)]
    audio_2 = audio_2[int((10-prev_file_end_secs)*Fs):]
    audio = np.concatenate((audio_1, audio_2), axis=None)
    return audio

def file_flagger(file_name, check_point, rainfall):
    check_point = check_point.replace(microsecond=0)
    fname_time = get_fname_time(file_name).replace(microsecond=0)
    fname_end_time = fname_time+timedelta(seconds=10)
    duration = fname_end_time-check_point
    selection_flag, partial, current_file_init_secs, prev_file_end_secs = evaluate_duration(duration)
    if selection_flag and not partial:
        file_path = join(NON_MECH_PATH, file_name)
        audio, Fs, duration = load_wav(file_path)
        print("Reading the full file: ", file_name)
    elif selection_flag and partial:
        prev_file_to_read = get_previous_file(file_name, wave_files)
        if prev_file_to_read:
            file_path_1 = join(NON_MECH_PATH, file_name)
            file_path_2 = join(NON_MECH_PATH, prev_file_to_read)
            print("Reading initial of {} and end of {}".format(file_name, prev_file_to_read))
            audio = read_and_merge_files(file_path_1, file_path_2, current_file_init_secs, prev_file_end_secs)
        else:
            audio = np.zeros(MAX_LEN)
    elif not selection_flag:
        audio = np.zeros(MAX_LEN)
    return audio, selection_flag

# %%
data_basic = pd.DataFrame()
target = np.array([])
for idx, row in mech_data.iterrows():
    check_point = row["time"]
    rainfall = row["rainfall"]
    for wave_file in wave_files:
        audio_sample, selection_flag = file_flagger(wave_file, check_point, rainfall)
        if selection_flag:
            with open("audio_{}.npy".format(idx), "wb") as f:
                np.save(f, audio_sample)
            data_row = {"checkpoint": check_point,
                        "fname": "audio_{}.npy".format(idx), 
                        "target": row["rainfall"]}
            data_basic = pd.concat([data_basic, pd.DataFrame([data_row])], ignore_index=True)
        else:
            continue
# Out:
# Reading initial of 2024_04_11_22_21_01_206302.wav and end of 2024_04_11_22_20_51_032425.wav
# Reading initial of 2024_04_11_22_21_11_377146.wav and end of 2024_04_11_22_21_01_206302.wav
# Reading initial of 2024_04_11_22_21_21_550275.wav and end of 2024_04_11_22_21_11_377146.wav
# Reading initial of 2024_04_11_22_21_31_724199.wav and end of 2024_04_11_22_21_21_550275.wav
# Reading initial of 2024_04_11_22_21_41_895893.wav and end of 2024_04_11_22_21_31_724199.wav
# Reading initial of 2024_04_11_22_22_02_239525.wav and end of 2024_04_11_22_21_52_066773.wav
# Reading initial of 2024_04_11_22_22_12_413496.wav and end of 2024_04_11_22_22_02_239525.wav
# Reading initial of 2024_04_11_22_22_22_586632.wav and end of 2024_04_11_22_22_12_413496.wav
# Reading initial of 2024_04_11_22_22_32_760900.wav and end of 2024_04_11_22_22_22_586632.wav
# Reading initial of 2024_04_11_22_43_27_627611.wav and end of 2024_04_11_22_43_17_453961.wav
# Reading initial of 2024_04_11_22_43_37_799816.wav and end of 2024_04_11_22_43_27_627611.wav
# Reading initial of 2024_04_11_22_43_47_972481.wav and end of 2024_04_11_22_43_37_799816.wav
# Reading initial of 2024_04_11_22_44_08_320561.wav and end of 2024_04_11_22_43_58_147275.wav
# Reading initial of 2024_04_11_22_44_18_494560.wav and end of 2024_04_11_22_44_08_320561.wav
# Reading initial of 2024_04_11_22_44_28_669210.wav and end of 2024_04_11_22_44_18_494560.wav
# Reading initial of 2024_04_11_22_44_38_843951.wav and end of 2024_04_11_22_44_28_669210.wav
# Reading initial of 2024_04_12_12_17_10_909407.wav and end of 2024_04_12_12_17_00_760772.wav
# Reading initial of 2024_04_12_12_17_31_128266.wav and end of 2024_04_12_12_17_21_057069.wav
# Reading initial of 2024_04_12_12_17_41_279147.wav and end of 2024_04_12_12_17_31_128266.wav
# Reading initial of 2024_04_12_12_17_51_426941.wav and end of 2024_04_12_12_17_41_279147.wav
# Reading initial of 2024_04_12_12_28_33_197255.wav and end of 2024_04_12_12_28_23_048259.wav
# Reading initial of 2024_04_12_12_28_43_345011.wav and end of 2024_04_12_12_28_33_197255.wav
# Reading initial of 2024_04_12_12_28_53_492849.wav and end of 2024_04_12_12_28_43_345011.wav
# Reading initial of 2024_04_12_12_30_04_531198.wav and end of 2024_04_12_12_29_54_383237.wav
# Reading initial of 2024_04_12_12_30_14_679600.wav and end of 2024_04_12_12_30_04_531198.wav
# Reading initial of 2024_04_12_12_30_24_740051.wav and end of 2024_04_12_12_30_14_679600.wav
# Reading initial of 2024_04_12_12_30_48_391526.wav and end of 2024_04_12_12_30_38_244969.wav
# Reading initial of 2024_04_12_12_30_58_537891.wav and end of 2024_04_12_12_30_48_391526.wav
# Reading the full file:  2024_04_12_12_31_59_432203.wav
# Reading the full file:  2024_04_12_12_32_09_582572.wav
# Reading the full file:  2024_04_12_12_32_19_733082.wav
# Reading the full file:  2024_04_12_12_32_29_881041.wav
# Reading initial of 2024_04_12_12_32_50_180961.wav and end of 2024_04_12_12_32_40_030787.wav
# Reading initial of 2024_04_12_12_33_00_251043.wav and end of 2024_04_12_12_32_50_180961.wav
# Reading initial of 2024_04_12_12_33_10_400929.wav and end of 2024_04_12_12_33_00_251043.wav
# Reading initial of 2024_04_12_12_33_20_547619.wav and end of 2024_04_12_12_33_10_400929.wav
# Reading initial of 2024_04_12_12_33_30_696557.wav and end of 2024_04_12_12_33_20_547619.wav
# Reading initial of 2024_04_12_12_33_54_377054.wav and end of 2024_04_12_12_33_44_229291.wav
# Reading initial of 2024_04_12_12_34_04_526223.wav and end of 2024_04_12_12_33_54_377054.wav
# Reading initial of 2024_04_12_12_34_14_676764.wav and end of 2024_04_12_12_34_04_526223.wav
# Reading initial of 2024_04_12_12_34_24_747260.wav and end of 2024_04_12_12_34_14_676764.wav
# Reading initial of 2024_04_12_12_34_34_804098.wav and end of 2024_04_12_12_34_24_747260.wav
# Reading initial of 2024_04_12_12_34_44_952017.wav and end of 2024_04_12_12_34_34_804098.wav
# Reading initial of 2024_04_12_12_35_05_248666.wav and end of 2024_04_12_12_34_55_098538.wav
# Reading initial of 2024_04_12_12_35_15_397222.wav and end of 2024_04_12_12_35_05_248666.wav
# Reading initial of 2024_04_12_12_35_25_467716.wav and end of 2024_04_12_12_35_15_397222.wav
# Reading initial of 2024_04_12_12_35_35_617593.wav and end of 2024_04_12_12_35_25_467716.wav
# Reading initial of 2024_04_12_12_35_45_765763.wav and end of 2024_04_12_12_35_35_617593.wav
# Reading initial of 2024_04_12_12_35_55_915479.wav and end of 2024_04_12_12_35_45_765763.wav
# Reading initial of 2024_04_12_12_36_16_211193.wav and end of 2024_04_12_12_36_06_064040.wav
# Reading initial of 2024_04_12_12_36_26_360061.wav and end of 2024_04_12_12_36_16_211193.wav
# Reading initial of 2024_04_12_12_36_36_418235.wav and end of 2024_04_12_12_36_26_360061.wav
# Reading the full file:  2024_04_12_12_36_49_923375.wav
# Reading initial of 2024_04_12_12_37_10_220426.wav and end of 2024_04_12_12_37_00_072150.wav
# Reading initial of 2024_04_12_12_37_20_370459.wav and end of 2024_04_12_12_37_10_220426.wav
# Reading initial of 2024_04_12_12_37_30_519073.wav and end of 2024_04_12_12_37_20_370459.wav
# Reading initial of 2024_04_12_12_37_40_668710.wav and end of 2024_04_12_12_37_30_519073.wav
# Reading initial of 2024_04_12_12_37_50_740619.wav and end of 2024_04_12_12_37_40_668710.wav
# Reading initial of 2024_04_12_12_38_00_890413.wav and end of 2024_04_12_12_37_50_740619.wav
# Reading initial of 2024_04_12_12_38_21_191918.wav and end of 2024_04_12_12_38_11_040161.wav
# Reading initial of 2024_04_12_12_38_31_342521.wav and end of 2024_04_12_12_38_21_191918.wav
# Reading initial of 2024_04_12_12_38_41_488689.wav and end of 2024_04_12_12_38_31_342521.wav
# Reading initial of 2024_04_12_12_38_51_637009.wav and end of 2024_04_12_12_38_41_488689.wav
# Reading initial of 2024_04_12_12_39_01_786763.wav and end of 2024_04_12_12_38_51_637009.wav
# Reading initial of 2024_04_12_12_39_11_935424.wav and end of 2024_04_12_12_39_01_786763.wav
# Reading initial of 2024_04_12_12_39_32_152990.wav and end of 2024_04_12_12_39_22_004345.wav
# Reading initial of 2024_04_12_12_39_42_302655.wav and end of 2024_04_12_12_39_32_152990.wav
# Reading initial of 2024_04_12_12_40_05_996613.wav and end of 2024_04_12_12_39_55_847143.wav
# Reading initial of 2024_04_12_12_40_26_294997.wav and end of 2024_04_12_12_40_16_145619.wav
# Reading initial of 2024_04_12_12_40_36_443926.wav and end of 2024_04_12_12_40_26_294997.wav
# Reading initial of 2024_04_12_12_40_46_595443.wav and end of 2024_04_12_12_40_36_443926.wav
# Reading initial of 2024_04_12_12_40_56_743560.wav and end of 2024_04_12_12_40_46_595443.wav
# Reading initial of 2024_04_12_12_41_06_890944.wav and end of 2024_04_12_12_40_56_743560.wav
# Reading initial of 2024_04_12_12_41_27_190212.wav and end of 2024_04_12_12_41_17_039409.wav
# Reading initial of 2024_04_12_12_41_37_338948.wav and end of 2024_04_12_12_41_27_190212.wav
# Reading initial of 2024_04_12_12_41_47_487283.wav and end of 2024_04_12_12_41_37_338948.wav
# Reading initial of 2024_04_12_12_41_57_633786.wav and end of 2024_04_12_12_41_47_487283.wav
# Reading initial of 2024_04_12_12_42_07_782421.wav and end of 2024_04_12_12_41_57_633786.wav
# Reading initial of 2024_04_12_12_42_17_930898.wav and end of 2024_04_12_12_42_07_782421.wav
# Reading initial of 2024_04_12_12_42_38_228705.wav and end of 2024_04_12_12_42_28_079633.wav
# Reading initial of 2024_04_12_12_42_48_380898.wav and end of 2024_04_12_12_42_38_228705.wav
# Reading initial of 2024_04_12_12_43_22_083266.wav and end of 2024_04_12_12_43_12_022829.wav
# Reading initial of 2024_04_12_12_43_32_231845.wav and end of 2024_04_12_12_43_22_083266.wav
# Reading initial of 2024_04_12_12_43_42_293633.wav and end of 2024_04_12_12_43_32_231845.wav
# Reading initial of 2024_04_12_12_43_52_444430.wav and end of 2024_04_12_12_43_42_293633.wav
# Reading initial of 2024_04_12_12_44_02_594061.wav and end of 2024_04_12_12_43_52_444430.wav
# Reading initial of 2024_04_12_12_44_12_742649.wav and end of 2024_04_12_12_44_02_594061.wav
# Reading initial of 2024_04_12_12_44_22_892060.wav and end of 2024_04_12_12_44_12_742649.wav
# Reading initial of 2024_04_12_12_44_43_111527.wav and end of 2024_04_12_12_44_33_039216.wav
# Reading initial of 2024_04_12_12_44_53_260477.wav and end of 2024_04_12_12_44_43_111527.wav
# Reading initial of 2024_04_12_12_45_03_408084.wav and end of 2024_04_12_12_44_53_260477.wav
# Reading initial of 2024_04_12_12_45_13_468836.wav and end of 2024_04_12_12_45_03_408084.wav
# Reading initial of 2024_04_12_12_45_23_537119.wav and end of 2024_04_12_12_45_13_468836.wav
# Reading initial of 2024_04_12_12_45_33_688946.wav and end of 2024_04_12_12_45_23_537119.wav
# Reading initial of 2024_04_12_12_45_43_839355.wav and end of 2024_04_12_12_45_33_688946.wav
# Reading initial of 2024_04_12_12_45_53_987206.wav and end of 2024_04_12_12_45_43_839355.wav
# Reading initial of 2024_04_12_12_46_17_467961.wav and end of 2024_04_12_12_46_07_409669.wav
# Reading initial of 2024_04_12_12_46_27_617609.wav and end of 2024_04_12_12_46_17_467961.wav
# Reading initial of 2024_04_12_12_46_37_765425.wav and end of 2024_04_12_12_46_27_617609.wav
# Reading initial of 2024_04_12_12_46_47_914018.wav and end of 2024_04_12_12_46_37_765425.wav
# Reading initial of 2024_04_12_12_47_08_211188.wav and end of 2024_04_12_12_46_58_062966.wav
# Reading initial of 2024_04_12_12_47_18_361863.wav and end of 2024_04_12_12_47_08_211188.wav
# Reading initial of 2024_04_12_12_47_28_511128.wav and end of 2024_04_12_12_47_18_361863.wav
# Reading initial of 2024_04_12_12_47_38_659314.wav and end of 2024_04_12_12_47_28_511128.wav
# Reading initial of 2024_04_12_12_47_48_730354.wav and end of 2024_04_12_12_47_38_659314.wav
# Reading initial of 2024_04_12_12_47_58_881050.wav and end of 2024_04_12_12_47_48_730354.wav
# Reading the full file:  2024_04_12_12_48_09_030992.wav
# Reading the full file:  2024_04_12_12_48_19_179540.wav
# Reading the full file:  2024_04_12_12_48_29_326856.wav
# Reading the full file:  2024_04_12_12_48_39_476141.wav
# Reading the full file:  2024_04_12_12_48_49_623440.wav
# Reading the full file:  2024_04_12_12_48_59_773968.wav
# Reading initial of 2024_04_12_12_49_23_370935.wav and end of 2024_04_12_12_49_13_221932.wav
# Reading initial of 2024_04_12_12_49_33_520970.wav and end of 2024_04_12_12_49_23_370935.wav
# Reading initial of 2024_04_12_12_49_43_672584.wav and end of 2024_04_12_12_49_33_520970.wav
# Reading initial of 2024_04_12_12_49_53_821525.wav and end of 2024_04_12_12_49_43_672584.wav
# Reading initial of 2024_04_12_12_50_03_971736.wav and end of 2024_04_12_12_49_53_821525.wav
# Reading initial of 2024_04_12_12_50_24_271214.wav and end of 2024_04_12_12_50_14_120494.wav
# Reading initial of 2024_04_12_12_50_34_420663.wav and end of 2024_04_12_12_50_24_271214.wav
# Reading initial of 2024_04_12_12_50_44_571177.wav and end of 2024_04_12_12_50_34_420663.wav
# Reading initial of 2024_04_12_12_50_54_721399.wav and end of 2024_04_12_12_50_44_571177.wav
# Reading initial of 2024_04_12_12_52_05_578359.wav and end of 2024_04_12_12_51_55_523106.wav
# Reading the full file:  2024_04_12_12_52_19_059617.wav
# Reading the full file:  2024_04_12_12_52_29_208548.wav
# Reading the full file:  2024_04_12_12_52_39_362146.wav
# Reading the full file:  2024_04_12_12_52_49_512114.wav
# Reading initial of 2024_04_12_12_57_06_314379.wav and end of 2024_04_12_12_56_56_164460.wav
# Reading initial of 2024_04_12_12_57_16_372298.wav and end of 2024_04_12_12_57_06_314379.wav
# Reading initial of 2024_04_12_12_57_26_520592.wav and end of 2024_04_12_12_57_16_372298.wav
# Reading initial of 2024_04_12_12_57_36_669651.wav and end of 2024_04_12_12_57_26_520592.wav
# Reading initial of 2024_04_12_12_57_46_818985.wav and end of 2024_04_12_12_57_36_669651.wav
# Reading initial of 2024_04_12_12_57_56_969513.wav and end of 2024_04_12_12_57_46_818985.wav
# Reading initial of 2024_04_12_13_08_07_966154.wav and end of 2024_04_12_13_07_57_817048.wav
# Reading initial of 2024_04_12_13_08_28_263431.wav and end of 2024_04_12_13_08_18_113616.wav
# Reading initial of 2024_04_12_13_08_38_412636.wav and end of 2024_04_12_13_08_28_263431.wav
# Reading initial of 2024_04_13_00_23_15_368076.wav and end of 2024_04_13_00_23_05_195234.wav
# Reading initial of 2024_04_13_00_23_25_541167.wav and end of 2024_04_13_00_23_15_368076.wav
# Reading initial of 2024_04_13_00_23_35_713603.wav and end of 2024_04_13_00_23_25_541167.wav
# Reading initial of 2024_04_13_00_23_45_887727.wav and end of 2024_04_13_00_23_35_713603.wav
# Reading initial of 2024_04_13_00_24_06_234395.wav and end of 2024_04_13_00_23_56_059734.wav
# Reading initial of 2024_04_13_00_24_16_409710.wav and end of 2024_04_13_00_24_06_234395.wav
# Reading initial of 2024_04_13_00_24_26_583834.wav and end of 2024_04_13_00_24_16_409710.wav
# Reading initial of 2024_04_13_06_02_02_429257.wav and end of 2024_04_13_06_01_52_255898.wav
# Reading initial of 2024_04_13_15_00_01_879516.wav and end of 2024_04_13_14_59_51_707738.wav
# Reading initial of 2024_04_13_15_00_36_194398.wav and end of 2024_04_13_15_00_26_023250.wav
# Reading initial of 2024_04_13_15_00_46_368075.wav and end of 2024_04_13_15_00_36_194398.wav
# Reading initial of 2024_04_13_15_00_56_541055.wav and end of 2024_04_13_15_00_46_368075.wav
# Reading initial of 2024_04_13_15_10_06_434469.wav and end of 2024_04_13_15_09_56_260616.wav
# Reading initial of 2024_04_13_15_10_16_609063.wav and end of 2024_04_13_15_10_06_434469.wav
# Reading initial of 2024_04_13_15_10_26_781020.wav and end of 2024_04_13_15_10_16_609063.wav
# Reading initial of 2024_04_13_15_10_36_952518.wav and end of 2024_04_13_15_10_26_781020.wav
# Reading initial of 2024_04_13_15_10_57_297899.wav and end of 2024_04_13_15_10_47_125882.wav
# Reading initial of 2024_04_13_15_11_07_471140.wav and end of 2024_04_13_15_10_57_297899.wav
# Reading initial of 2024_04_13_15_11_17_643992.wav and end of 2024_04_13_15_11_07_471140.wav
# Reading initial of 2024_04_13_15_11_27_817665.wav and end of 2024_04_13_15_11_17_643992.wav
# Reading initial of 2024_04_13_15_11_37_990503.wav and end of 2024_04_13_15_11_27_817665.wav
# Reading initial of 2024_04_13_15_11_58_336739.wav and end of 2024_04_13_15_11_48_164091.wav
# Reading initial of 2024_04_13_15_12_08_508228.wav and end of 2024_04_13_15_11_58_336739.wav
# Reading initial of 2024_04_13_15_12_18_680357.wav and end of 2024_04_13_15_12_08_508228.wav
# Reading initial of 2024_04_13_15_12_28_854039.wav and end of 2024_04_13_15_12_18_680357.wav
# Reading initial of 2024_04_13_15_12_52_715732.wav and end of 2024_04_13_15_12_42_543387.wav
# Reading initial of 2024_04_13_15_13_02_888677.wav and end of 2024_04_13_15_12_52_715732.wav
# Reading initial of 2024_04_13_15_13_23_234019.wav and end of 2024_04_13_15_13_13_060652.wav
# Reading initial of 2024_04_13_15_13_33_407212.wav and end of 2024_04_13_15_13_23_234019.wav
# Reading initial of 2024_04_13_15_13_43_578679.wav and end of 2024_04_13_15_13_33_407212.wav
# Reading initial of 2024_04_13_15_13_53_749137.wav and end of 2024_04_13_15_13_43_578679.wav
# Reading initial of 2024_04_13_15_14_03_923899.wav and end of 2024_04_13_15_13_53_749137.wav
# Reading initial of 2024_04_13_15_14_24_271350.wav and end of 2024_04_13_15_14_14_096968.wav
# Reading initial of 2024_04_13_15_14_34_443146.wav and end of 2024_04_13_15_14_24_271350.wav
# Reading initial of 2024_04_13_15_14_44_616557.wav and end of 2024_04_13_15_14_34_443146.wav
# Reading initial of 2024_04_13_15_14_54_789204.wav and end of 2024_04_13_15_14_44_616557.wav
# Reading initial of 2024_04_13_15_15_04_962953.wav and end of 2024_04_13_15_14_54_789204.wav
# Reading initial of 2024_04_13_15_15_25_309517.wav and end of 2024_04_13_15_15_15_136570.wav
# Reading initial of 2024_04_13_15_15_35_480882.wav and end of 2024_04_13_15_15_25_309517.wav
# Reading the full file:  2024_04_13_15_15_49_063946.wav
# Reading the full file:  2024_04_13_15_15_59_237587.wav
# Reading the full file:  2024_04_13_15_16_09_411394.wav
# Reading the full file:  2024_04_13_15_16_19_584417.wav
# Reading the full file:  2024_04_13_15_16_29_759946.wav
# Reading the full file:  2024_04_13_15_16_39_934679.wav
# Reading initial of 2024_04_13_15_17_00_280966.wav and end of 2024_04_13_15_16_50_108494.wav
# Reading initial of 2024_04_13_15_17_10_454892.wav and end of 2024_04_13_15_17_00_280966.wav
# Reading initial of 2024_04_13_15_17_20_628600.wav and end of 2024_04_13_15_17_10_454892.wav
# Reading initial of 2024_04_13_15_17_30_802302.wav and end of 2024_04_13_15_17_20_628600.wav
# Reading initial of 2024_04_13_15_17_40_973185.wav and end of 2024_04_13_15_17_30_802302.wav
# Reading initial of 2024_04_13_15_18_01_318792.wav and end of 2024_04_13_15_17_51_145570.wav
# Reading initial of 2024_04_13_15_18_11_491112.wav and end of 2024_04_13_15_18_01_318792.wav
# Reading initial of 2024_04_13_15_18_21_663539.wav and end of 2024_04_13_15_18_11_491112.wav
# Reading initial of 2024_04_13_15_18_31_836982.wav and end of 2024_04_13_15_18_21_663539.wav
# Reading initial of 2024_04_13_15_22_12_284152.wav and end of 2024_04_13_15_22_02_112419.wav
# Reading initial of 2024_04_13_15_22_22_457620.wav and end of 2024_04_13_15_22_12_284152.wav
# Reading initial of 2024_04_13_15_22_32_629991.wav and end of 2024_04_13_15_22_22_457620.wav
# Reading initial of 2024_04_13_15_22_42_801848.wav and end of 2024_04_13_15_22_32_629991.wav
# Reading initial of 2024_04_13_15_22_52_975238.wav and end of 2024_04_13_15_22_42_801848.wav
# Reading initial of 2024_04_13_15_25_18_805190.wav and end of 2024_04_13_15_25_08_630962.wav
# Reading initial of 2024_04_13_15_25_28_976853.wav and end of 2024_04_13_15_25_18_805190.wav
# Reading the full file:  2024_04_13_15_25_39_150367.wav
# Reading the full file:  2024_04_13_15_25_49_324512.wav
# Reading the full file:  2024_04_13_15_25_59_498786.wav
# Reading the full file:  2024_04_13_15_26_09_672793.wav
# Reading the full file:  2024_04_13_15_26_19_847714.wav
# Reading initial of 2024_04_13_15_26_40_194292.wav and end of 2024_04_13_15_26_30_021731.wav
# Reading initial of 2024_04_13_15_26_50_367336.wav and end of 2024_04_13_15_26_40_194292.wav
# Reading initial of 2024_04_13_15_27_00_541658.wav and end of 2024_04_13_15_26_50_367336.wav
# Reading initial of 2024_04_13_15_27_10_715455.wav and end of 2024_04_13_15_27_00_541658.wav
# Reading initial of 2024_04_13_15_27_20_888253.wav and end of 2024_04_13_15_27_10_715455.wav
# Reading initial of 2024_04_13_15_27_41_232455.wav and end of 2024_04_13_15_27_31_061024.wav
# Reading initial of 2024_04_13_15_27_51_405957.wav and end of 2024_04_13_15_27_41_232455.wav
# Reading initial of 2024_04_13_15_28_01_578660.wav and end of 2024_04_13_15_27_51_405957.wav
# Reading initial of 2024_04_13_15_28_25_289645.wav and end of 2024_04_13_15_28_15_115882.wav
# Reading initial of 2024_04_13_15_28_35_461833.wav and end of 2024_04_13_15_28_25_289645.wav
# Reading initial of 2024_04_13_15_28_45_634228.wav and end of 2024_04_13_15_28_35_461833.wav
# Reading initial of 2024_04_13_15_28_55_805951.wav and end of 2024_04_13_15_28_45_634228.wav
# Reading initial of 2024_04_13_15_29_05_980101.wav and end of 2024_04_13_15_28_55_805951.wav
# Reading initial of 2024_04_13_15_29_26_327118.wav and end of 2024_04_13_15_29_16_152993.wav
# Reading initial of 2024_04_13_15_29_36_498001.wav and end of 2024_04_13_15_29_26_327118.wav
# Reading initial of 2024_04_13_15_29_46_671808.wav and end of 2024_04_13_15_29_36_498001.wav
# Reading initial of 2024_04_13_15_29_56_844825.wav and end of 2024_04_13_15_29_46_671808.wav
# Reading initial of 2024_04_14_06_01_10_337702.wav and end of 2024_04_14_06_01_00_163926.wav
# Reading initial of 2024_04_14_06_01_20_509592.wav and end of 2024_04_14_06_01_10_337702.wav
# Reading initial of 2024_04_14_06_01_30_681409.wav and end of 2024_04_14_06_01_20_509592.wav
# Reading initial of 2024_04_14_06_01_40_854863.wav and end of 2024_04_14_06_01_30_681409.wav
# Reading initial of 2024_04_15_06_00_32_201290.wav and end of 2024_04_15_06_00_22_116256.wav
# Reading initial of 2024_04_15_06_00_42_285196.wav and end of 2024_04_15_06_00_32_201290.wav
# Reading initial of 2024_04_15_06_00_52_367266.wav and end of 2024_04_15_06_00_42_285196.wav

# %%
data_basic
# Out:
#                     checkpoint          fname  target
# 0   2024-04-11 22:20:59.757439    audio_0.npy     0.0
# 1   2024-04-11 22:21:09.757439    audio_1.npy     0.0
# 2   2024-04-11 22:21:19.757438    audio_2.npy     0.0
# 3   2024-04-11 22:21:29.757440    audio_3.npy     0.0
# 4   2024-04-11 22:21:39.757440    audio_4.npy     0.0
# ..                         ...            ...     ...
# 266 2024-04-14 06:01:59.757438  audio_275.npy     0.2
# 267 2024-04-15 06:00:29.757440  audio_283.npy     0.0
# 268 2024-04-15 06:00:39.757441  audio_284.npy     0.0
# 269 2024-04-15 06:00:49.757439  audio_285.npy     0.0
# 270 2024-04-15 06:00:59.757438  audio_286.npy     0.0
#
# [271 rows x 3 columns]

# %%
data_basic.to_csv("data_basic.csv")
mech_data.to_csv("mech_data.csv")

# %%
mech_data
# Out:
#                           time  rainfall
# 0   2024-04-11 22:20:59.757439       0.0
# 1   2024-04-11 22:21:09.757439       0.0
# 2   2024-04-11 22:21:19.757438       0.0
# 3   2024-04-11 22:21:29.757440       0.0
# 4   2024-04-11 22:21:39.757440       0.0
# ..                         ...       ...
# 282 2024-04-15 06:00:19.766818       0.2
# 283 2024-04-15 06:00:29.757440       0.0
# 284 2024-04-15 06:00:39.757441       0.0
# 285 2024-04-15 06:00:49.757439       0.0
# 286 2024-04-15 06:00:59.757438       0.0
#
# [287 rows x 2 columns]
